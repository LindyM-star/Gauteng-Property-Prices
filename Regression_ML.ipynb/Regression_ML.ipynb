# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

raw_data = pd.read_csv('dataset.csv')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 888 entries, 0 to 887
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bathrooms         888 non-null    float64
#  1   Bedrooms          888 non-null    float64
#  2   Erf Size          888 non-null    float64
#  3   Garages           888 non-null    float64
#  4   Lat               888 non-null    float64
#  5   Long              888 non-null    float64
#  6   Price             888 non-null    float64
#  7   Type of Property  888 non-null    object
#  8   Listing Date      888 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 62.6+ KB

# %%
sns.pairplot(raw_data)

# %%
x = raw_data[['Bathrooms', 'Bedrooms','Erf Size','Garages' ]]

# %%
y = raw_data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [ 6.57789771e+05  1.04925609e+05 -3.75497415e+00  6.59159704e+05]

# %%
pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])
# Out:
#                    Coeff
# Bathrooms  657789.770968
# Bedrooms   104925.609260
# Erf Size       -3.754974
# Garages    659159.704127

# %%
predictions = model.predict(x_test)

# %%
plt.hist(y_test - predictions)
# Out:
# (array([ 43., 124.,  10.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([-3055959.74288745,  -620347.18929746,  1815265.36429254,
#          4250877.91788253,  6686490.47147253,  9122103.02506253,
#         11557715.57865252, 13993328.13224252, 16428940.68583251,
#         18864553.23942251, 21300165.79301251]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 827413.3301857086

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 3510321294027.269

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 1873585.1445897166

# %%
predictions
# Out:
# array([1038964.55666314, 1039704.28657048, 1697328.83867595,
#        3220434.63772841, 1038169.13454882, 2460621.85251758,
#        1142738.02126459, 1038964.55666314, 3428919.67806328,
#        3220250.01158987, 1038964.55666314, 1801649.89709789,
#        3223712.7301604 , 1905118.57638803, 1801724.99658087,
#        2011745.1889374 , 1142520.23276395, 1801679.93689108,
#        1035310.96681626, 1038964.55666314, 1901930.60333561,
#        1801465.90336459, 3326329.66272399, 1875544.39999125,
#         380473.23793452, 1696754.32763117, 1801679.93689108,
#        1039704.28657048, 1801679.93689108, 1801826.38088289,
#        1802378.36208278, 2561086.55248859, 1801679.93689108,
#        1796509.33748804, 1697392.67323648, 1801931.52015906,
#        2561882.60700816, 1801679.93689108, 1801428.35362311,
#        2460839.64101821, 8699834.20698749, 1906605.546151  ,
#        1904089.71347123, 1802322.03747054,  934752.39249152,
#        1906688.15558227, 1906087.35971845, 3222473.58869127,
